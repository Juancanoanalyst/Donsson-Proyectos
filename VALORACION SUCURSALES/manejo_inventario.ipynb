# %% [markdown]
# ## MODELOS DISPONIBLES

# %%
#!/usr/bin/env python
import xmlrpc.client as xmlrpc 
import datetime as dt

ODOO_SERVER_USER = "juan.cano@donsson.com" #mi usuario 
ODOO_SERVER_PASSWORD = "1000285668" #mi contraseña de odoo 
ODOO_SERVER_URL = "https://donsson.com" #produccion url 
ODOO_SERVER_DATABASE = "Donsson_produccion" # 

###define los objetos del servidor#common: Establece la conexion#uid: Id del usuario en odoo#models: Modelos de odoo(tablas)
common = xmlrpc.ServerProxy("{}/xmlrpc/2/common".format(ODOO_SERVER_URL))
uid = common.authenticate(ODOO_SERVER_DATABASE, ODOO_SERVER_USER, ODOO_SERVER_PASSWORD, {})
models = xmlrpc.ServerProxy("{}/xmlrpc/2/object".format(ODOO_SERVER_URL))
l6m = (dt.datetime.today()-dt.timedelta(days=30)).strftime("%Y-%m-01 00:00:00") #1 meses antes desde hoy

#Consulta basica metodo search_read: Busca y lee la informacion
#Tabla ventas.perdidas(Esta tabla registra la causa de no venta por las cotizaciones y el punto de venta)
#filtrados por la variable l6m por el campo create_date(fecha de creacion).
#Extrae la informacion de las columnas 
#warehouse_id: id de la bodega en la tabla stock.warehouse(Almacenes)
#create_date: fecha de creacion(esta fecha es cuando se crea el registro en la base de datos )
#cliente_id: id del cliente en la tabla res.partner(Clientes)
#product_id: id del producto en la tabla product.template(Productos)
#cantidad: cantidad reportada(entero)
#cantidad_existencia:  cantidad en existencias en el momento de reporte(entero)
#cantidad_reservada: cantidad en reservas en el momento de reporte(entero)
#almacenamiento_tipo: Almacenamiento campo autocalculado en la cotizacion e ingresado desde el punto de venta (Agotado, En stock)

# Listar todos los modelos disponibles
modelos_disponibles = models.execute_kw(ODOO_SERVER_DATABASE, uid, ODOO_SERVER_PASSWORD,
    'ir.model', 'search_read',
    [[['model', 'ilike', 'cost']]],
    {'fields': ['model', 'name']}
)

for m in modelos_disponibles:
    print(m)
# Out:
# {'model': 'account.analytic.cost.ledger', 'id': 268, 'name': 'Account Analytic Cost Ledger'}
# {'model': 'account.analytic.cost.ledger.journal.report', 'id': 269, 'name': 'Account Analytic Cost Ledger For Journal Report'}
# {'model': 'cs.analisis.costo', 'id': 1088, 'name': 'Cadena de suministro analisis del nivel de servicio'}
# {'model': 'fleet.vehicle.cost', 'id': 710, 'name': 'Cost related to a vehicle'}
# {'model': 'mrp.bom.cost', 'id': 924, 'name': 'mrp.bom.cost'}
# {'model': 'mrp.bom.cost.lines', 'id': 925, 'name': 'mrp.bom.cost.lines'}
# {'model': 'mrp.costo.detallado', 'id': 1070, 'name': 'Costo detallado de la produccion'}
# {'model': 'report.account.report_analyticcostledger', 'id': 263, 'name': 'report.account.report_analyticcostledger'}
# {'model': 'report.account.report_analyticcostledgerquantity', 'id': 264, 'name': 'report.account.report_analyticcostledgerquantity'}
# {'model': 'stock.landed.cost', 'id': 611, 'name': 'Stock Landed Cost'}
# {'model': 'stock.landed.cost.lines', 'id': 612, 'name': 'Stock Landed Cost Lines'}

# %% [markdown]
# ## EXTRAER COSTO INVENTARIO

# %% [markdown]
# ### COLUMNAS ACTUALES

# %%
import xmlrpc.client
import pandas as pd

# Conexión con Odoo
username = "juan.cano@donsson.com"  # tu usuario
password = "1000285668"         # tu contraseña
url = "https://donsson.com"     # URL del servidor
db = "Donsson_produccion" # nombre de la base de datos

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")




fields_info = models.execute_kw(
    db, uid, password,
    'account.invoice.line',  # Nombre técnico del modelo
    'fields_get',
    []
)

# Convertir a DataFrame para visualizar mejor
df_campos = pd.DataFrame.from_dict(fields_info, orient='index')
df_campos
# Out:
#                      sortable  \
# origin                   True
# uos_id                   True
# create_date              True
# sequence                 True
# price_unit               True
# price_subtotal           True
# write_uid                True
# partner_id               True
# id                       True
# create_uid               True
# asset_category_id        True
# __last_update           False
# product_cost             True
# analytics_id             True
# company_id               True
# account_analytic_id      True
# purchase_line_id         True
# importacion              True
# account_id               True
# invoice_line_tax_id      True
# discount                 True
# move_line_ids            True
# write_date               True
# display_name            False
# product_id               True
# name                     True
# invoice_id               True
# quantity                 True
#
#                                                                   help  \
# origin               Reference of the document that produced this i...
# uos_id                                                             NaN
# create_date                                                        NaN
# sequence             Gives the sequence of this line when displayin...
# price_unit                                                         NaN
# price_subtotal                                                     NaN
# write_uid                                                          NaN
# partner_id                                                         NaN
# id                                                                 NaN
# create_uid                                                         NaN
# asset_category_id                                                  NaN
# __last_update                                                      NaN
# product_cost                                                       NaN
# analytics_id                                                       NaN
# company_id                                                         NaN
# account_analytic_id                                                NaN
# purchase_line_id                                                   NaN
# importacion                                   Número de la importación
# account_id           The income or expense account related to the s...
# invoice_line_tax_id                                                NaN
# discount                                                           NaN
# move_line_ids        Related stock moves (only when the invoice has...
# write_date                                                         NaN
# display_name                                                       NaN
# product_id                                                         NaN
# name                                                               NaN
# invoice_id                                                         NaN
# quantity                                                           NaN
#
#                      searchable  required  manual  readonly  \
# origin                     True     False   False     False
# uos_id                     True     False   False     False
# create_date                True     False   False     False
# sequence                   True     False   False     False
# price_unit                 True      True   False     False
# price_subtotal             True     False   False      True
# write_uid                  True     False   False     False
# partner_id                 True     False   False      True
# id                         True     False   False      True
# create_uid                 True     False   False     False
# asset_category_id          True     False   False     False
# __last_update             False     False   False      True
# product_cost               True     False   False     False
# analytics_id               True     False   False     False
# company_id                 True     False   False      True
# account_analytic_id        True     False   False     False
# purchase_line_id           True     False   False      True
# importacion                True     False   False     False
# account_id                 True      True   False     False
# invoice_line_tax_id        True     False   False     False
# discount                   True     False   False     False
# move_line_ids              True     False   False      True
# write_date                 True     False   False     False
# display_name              False     False   False      True
# product_id                 True     False   False     False
# name                       True      True   False     False
# invoice_id                 True     False   False     False
# quantity                   True      True   False     False
#
#                                                                depends  \
# origin                                                              []
# uos_id                                                              []
# create_date                                                         []
# sequence                                                            []
# price_unit                                                          []
# price_subtotal       [price_unit, discount, invoice_line_tax_id, qu...
# write_uid                                                           []
# partner_id                                     [invoice_id.partner_id]
# id                                                                  []
# create_uid                                                          []
# asset_category_id                                                   []
# __last_update                                [create_date, write_date]
# product_cost                                                        []
# analytics_id                                                        []
# company_id                                     [invoice_id.company_id]
# account_analytic_id                                                 []
# purchase_line_id                                                    []
# importacion                                                         []
# account_id                                                          []
# invoice_line_tax_id                                                 []
# discount                                                            []
# move_line_ids                                                       []
# write_date                                                          []
# display_name                                                    [name]
# product_id                                                          []
# name                                                                []
# invoice_id                                                          []
# quantity                                                            []
#
#                      groups  company_dependent translate       type  store  \
# origin                False              False     False       char   True
# uos_id                False              False       NaN   many2one   True
# create_date           False              False       NaN   datetime   True
# sequence              False              False       NaN    integer   True
# price_unit            False              False       NaN      float   True
# price_subtotal        False              False       NaN      float   True
# write_uid             False              False       NaN   many2one   True
# partner_id            False              False       NaN   many2one   True
# id                    False              False       NaN    integer   True
# create_uid            False              False       NaN   many2one   True
# asset_category_id     False              False       NaN   many2one   True
# __last_update         False              False       NaN   datetime  False
# product_cost          False              False       NaN      float   True
# analytics_id          False              False       NaN   many2one   True
# company_id            False              False       NaN   many2one   True
# account_analytic_id   False              False       NaN   many2one   True
# purchase_line_id      False              False       NaN   many2one   True
# importacion           False              False       NaN   many2one   True
# account_id            False              False       NaN   many2one   True
# invoice_line_tax_id   False              False       NaN  many2many   True
# discount              False              False       NaN      float   True
# move_line_ids         False              False       NaN   one2many   True
# write_date            False              False       NaN   datetime   True
# display_name          False              False     False       char  False
# product_id            False              False       NaN   many2one   True
# name                  False              False     False       text   True
# invoice_id            False              False       NaN   many2one   True
# quantity              False              False       NaN      float   True
#
#                                     string                        relation  \
# origin                     Source Document                             NaN
# uos_id                     Unit of Measure                     product.uom
# create_date                     Created on                             NaN
# sequence                          Sequence                             NaN
# price_unit                      Unit Price                             NaN
# price_subtotal                      Amount                             NaN
# write_uid                  Last Updated by                       res.users
# partner_id                         Partner                     res.partner
# id                                      Id                             NaN
# create_uid                      Created by                       res.users
# asset_category_id           Asset Category          account.asset.category
# __last_update             Last Modified on                             NaN
# product_cost                Costo producto                             NaN
# analytics_id         Analytic Distribution  account.analytic.plan.instance
# company_id                         Company                     res.company
# account_analytic_id       Analytic Account        account.analytic.account
# purchase_line_id       Purchase Order Line             purchase.order.line
# importacion                    Importación                   foreign.trade
# account_id                         Account                 account.account
# invoice_line_tax_id                  Taxes                     account.tax
# discount                      Discount (%)                             NaN
# move_line_ids          Related Stock Moves                      stock.move
# write_date                 Last Updated on                             NaN
# display_name                  Display Name                             NaN
# product_id                         Product                 product.product
# name                           Description                             NaN
# invoice_id               Invoice Reference                 account.invoice
# quantity                          Quantity                             NaN
#
#                       digits                   related  \
# origin                   NaN                       NaN
# uos_id                   NaN                       NaN
# create_date              NaN                       NaN
# sequence                 NaN                       NaN
# price_unit           [16, 2]                       NaN
# price_subtotal       [16, 2]                       NaN
# write_uid                NaN                       NaN
# partner_id               NaN  [invoice_id, partner_id]
# id                       NaN                       NaN
# create_uid               NaN                       NaN
# asset_category_id        NaN                       NaN
# __last_update            NaN                       NaN
# product_cost             NaN                       NaN
# analytics_id             NaN                       NaN
# company_id               NaN  [invoice_id, company_id]
# account_analytic_id      NaN                       NaN
# purchase_line_id         NaN                       NaN
# importacion              NaN                       NaN
# account_id               NaN                       NaN
# invoice_line_tax_id      NaN                       NaN
# discount             [16, 2]                       NaN
# move_line_ids            NaN                       NaN
# write_date               NaN                       NaN
# display_name             NaN                       NaN
# product_id               NaN                       NaN
# name                     NaN                       NaN
# invoice_id               NaN                       NaN
# quantity             [16, 3]                       NaN
#
#                                                domain   relation_field
# origin                                            NaN              NaN
# uos_id                                            NaN              NaN
# create_date                                       NaN              NaN
# sequence                                          NaN              NaN
# price_unit                                        NaN              NaN
# price_subtotal                                    NaN              NaN
# write_uid                                         NaN              NaN
# partner_id                                        NaN              NaN
# id                                                NaN              NaN
# create_uid                                        NaN              NaN
# asset_category_id                                 NaN              NaN
# __last_update                                     NaN              NaN
# product_cost                                      NaN              NaN
# analytics_id                                      NaN              NaN
# company_id                                        NaN              NaN
# account_analytic_id                               NaN              NaN
# purchase_line_id                                  NaN              NaN
# importacion                        [[state, =, open]]              NaN
# account_id           [[type, not in, [view, closed]]]              NaN
# invoice_line_tax_id           [[parent_id, =, False]]              NaN
# discount                                          NaN              NaN
# move_line_ids                                     NaN  invoice_line_id
# write_date                                        NaN              NaN
# display_name                                      NaN              NaN
# product_id                                        NaN              NaN
# name                                              NaN              NaN
# invoice_id                                        NaN              NaN
# quantity                                          NaN              NaN

# %% [markdown]
# ### CARGA DATAFRAME UNIDO

# %%
import xmlrpc.client
import pandas as pd

# Conexión
username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")

# Campos a extraer
campos = [
    'producto_code',
    'almacen_id',
    'producto_costo_unitario',
    'clasificacion',
    'inventario_ideal',
    'producto_marca',
    'producto_code',
    'semana',
    'stock_actual',
    'product_name',
    'ano'
]

# Extraer en bloques
df_total = pd.DataFrame()
batch_size = 20000
offset = 0

while True:
    print(f"Cargando registros desde offset {offset}...")
    registros = models.execute_kw(
        db, uid, password,
        'cs.analisis.costo', 'search_read',
        [[]],  # Sin filtro de ciudad
        {'fields': campos, 'limit': batch_size, 'offset': offset}
    )
    
    if not registros:
        break

    df_parcial = pd.DataFrame(registros)
    df_total = pd.concat([df_total, df_parcial], ignore_index=True)
    offset += batch_size
# Out:
# Cargando registros desde offset 0...
# Cargando registros desde offset 20000...
# Cargando registros desde offset 40000...
# Cargando registros desde offset 60000...

# %% [markdown]
# ### EXPORTAR DATAFRAME

# %%
df_total.sample(10)
# Out:
#         ano  producto_costo_unitario clasificacion product_name  stock_actual  \
# 40704  2025                  9725.49             C  DCS00343139             0
# 6114   2025                 87818.08             C  BAE06284125             0
# 34901  2025                 17948.00             C  BLS00005125             1
# 20138  2025                 99352.88             C  DAE08141025             1
# 16502  2025                  8314.14             C  DAE01024122             0
# 30426  2025                  7239.00             C  DLS00307004             0
# 42752  2025                  3972.50             C  DAE61083115             0
# 37896  2025                 33893.70             C  BCX00219125             0
# 17017  2025                  2259.97             C  DCE00430189             0
# 15666  2025                 18250.00             C  DAE01031139             0
#
#        semana producto_marca                               almacen_id  \
# 40704      34          OTROS                               [4, NORTE]
# 6114       34        BALDWIN  [36, ANTIOQUEÑA DE LUBRICANTES SGP SAS]
# 34901      34        BALDWIN                        [42, BUCARAMANGA]
# 20138      34        DONSSON                     [47, MOSTRADOR COTA]
# 16502      34          OTROS                               [58, CALI]
# 30426      34      AUT*PARTS                          [3, VALLADOLID]
# 42752      34          OTROS                               [4, NORTE]
# 37896      34        BALDWIN                        [42, BUCARAMANGA]
# 17017      34      AUT*PARTS                               [58, CALI]
# 15666      34          OTROS                               [58, CALI]
#
#         producto_code  inventario_ideal       id
# 40704     139 F-7F401                 0  1549654
# 6114       125 PA1774                 0  1515064
# 34901          125 B9                 1  1543851
# 20138      025 DA8141                 1  1529088
# 16502      122 KAF719                 0  1525452
# 30426       004 GS307                 1  1539376
# 42752  115 8200371661                 0  1551702
# 37896       125 10021                 0  1546846
# 17017      189 ALG310                 0  1525967
# 15666      139 GA1031                 0  1524616

# %%
# Asegurarte de que todos los valores sean strings simples
df_total['sucursal_nombre'] = df_total['almacen_id'].apply(lambda x: x[1] if isinstance(x, list) and len(x) > 1 else None)
df_total = df_total.drop(columns=['almacen_id', 'id'])
df_total =  df_total[['sucursal_nombre','producto_marca','product_name','producto_code','clasificacion','stock_actual','inventario_ideal','producto_costo_unitario','semana','ano']]

# Exportar

semana_unica = df_total["semana"].unique()

# Validación
if len(semana_unica) != 1:
    raise ValueError(f"Hay más de una semana en los datos: {semana_unica}")

n_semana = int(semana_unica[0])

# Guardar el archivo con el nombre de la semana
ruta_guardado = f'dataset/Entrada/df_completo_semana{n_semana}.csv'
df_total.to_csv(ruta_guardado, index=False)
print(f"Archivo guardado en: {ruta_guardado}")
# Out:
# Archivo guardado en: dataset/Entrada/df_completo_semana34.csv

# %%
# Ahora sí agrupar
agrupado = df_total.groupby('sucursal_nombre')['stock_actual'].sum().reset_index()
agrupado = agrupado.sort_values(by='stock_actual', ascending=False)
print(agrupado)
# Out:
#                      sucursal_nombre  stock_actual
# 8                         VALLADOLID         39301
# 1                       BARRANQUILLA         21839
# 5                           MEDELLIN         20362
# 2                        BUCARAMANGA         17796
# 3                               CALI         14629
# 4                            CALLE 6         10121
# 7                              NORTE          6427
# 6                     MOSTRADOR COTA          3480
# 0  ANTIOQUEÑA DE LUBRICANTES SGP SAS           880
