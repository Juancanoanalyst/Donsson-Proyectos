# %%
import xmlrpc.client
import pandas as pd


# Conexión con Odoo
username = "juan.cano@donsson.com"  # tu usuario
password = "1000285668"         # tu contraseña
url = "https://donsson.com"     # URL del servidor
db = "Donsson_produccion" # nombre de la base de datos

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")



nivel_servicio = models.execute_kw(
    db, uid, password,
    'nivel.servicio.wizard.reportresult',  # Nombre técnico del modelo
    'search_read',
    [[
        ('create_date', '>=', '2025-01-01 00:00:00'),
        ('create_date', '<=', '2025-12-31 23:59:59'),
    ]],
    {'fields': ['sucursal_id','marca','clase','producto_id','descripcion','septiembre_nv','septiembre_vp']}
)

# Convertir a DataFrame para visualizar mejor
df_campos = pd.DataFrame(nivel_servicio)
df_campos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4851 entries, 0 to 4850
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sucursal_id    4851 non-null   object
#  1   septiembre_nv  4851 non-null   float64
#  2   clase          4851 non-null   object
#  3   marca          4851 non-null   object
#  4   producto_id    4851 non-null   object
#  5   septiembre_vp  4851 non-null   float64
#  6   descripcion    4851 non-null   object
#  7   id             4851 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 303.3+ KB

# %%
df_campos.sample(10)
# Out:
#                      sucursal_id  septiembre_nv clase         marca  \
# 829   [11, SUCURSAL BUCARAMANGA]            1.0     B     AUT*PARTS
# 4258  [11, SUCURSAL BUCARAMANGA]            1.0     A       DONSSON
# 4096  [11, SUCURSAL BUCARAMANGA]            1.0     C       DONSSON
# 660   [11, SUCURSAL BUCARAMANGA]            1.0     C     AUT*PARTS
# 1206  [11, SUCURSAL BUCARAMANGA]            1.0     C  RACOR BRASIL
# 4763  [11, SUCURSAL BUCARAMANGA]            1.0     C         OTROS
# 2916  [11, SUCURSAL BUCARAMANGA]            1.0     C       BALDWIN
# 26    [11, SUCURSAL BUCARAMANGA]            1.0     C       DONSSON
# 758   [11, SUCURSAL BUCARAMANGA]            1.0     C       DONSSON
# 3158  [11, SUCURSAL BUCARAMANGA]            1.0     A       BALDWIN
#
#                                             producto_id  septiembre_vp  \
# 829   [36795, [DCE00868189] G868 FILTRO COMBUSTIBLE ...            0.0
# 4258  [17132, [DAB02702025] DA2702 FILTRO AIRE 1_ IS...            0.0
# ...
